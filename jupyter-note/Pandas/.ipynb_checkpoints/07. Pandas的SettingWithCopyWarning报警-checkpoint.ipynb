# %% [markdown]
# ### 0、读取数据

# %%
import pandas as pd

# %%
fpath = "./datas/beijing_tianqi/beijing_tianqi_2018.csv"
df = pd.read_csv(fpath)

# %%
df.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1

# %%
# 替换掉温度的后缀℃
df.loc[:, 'bWendu'] = df["bWendu"].str.replace("℃", "").astype('int32')
df.loc[:, 'yWendu'] = df["yWendu"].str.replace("℃", "").astype('int32')

# %%
df.head()
# Out:
#           ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03       2      -5     多云        北风   1-2级   28       优         1
# 3  2018-01-04       0      -8      阴       东北风   1-2级   28       优         1
# 4  2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优         1

# %% [markdown]
# ### 1、复现

# %%
# 只选出3月份的数据用于分析
condition = df["ymd"].str.startswith("2018-03")

# %%
# 设置温差
df[condition]["wen_cha"] = df["bWendu"] - df["yWendu"]
# Out:
# <ipython-input-8-55cdcbe54fde>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[condition]["wen_cha"] = df["bWendu"] - df["yWendu"]

# %%
df[condition].head()
# Out:
#            ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 59  2018-03-01       8      -3     多云       西南风   1-2级   46       优         1
# 60  2018-03-02       9      -1   晴~多云        北风   1-2级   95       良         2
# 61  2018-03-03      13       3   多云~阴        北风   1-2级  214    重度污染         5
# 62  2018-03-04       7      -2   阴~多云       东南风   1-2级  144    轻度污染         3
# 63  2018-03-05       8      -3      晴        南风   1-2级   94       良         2

# %% [markdown]
# ### 2、原因
# 发出警告的代码df[condition]["wencha_cha"] = df["bWendu"]- df["yWendu"]
#
# 相当于：df.get(condition).set(wen_cha),第一步骤的get发出了警报
#
# **链式操作其实是两个步骤，先get后set，get得到的dataframe可能是view也可能是copy，pandas发出警告**
#
# 核心要义：pandas的dataframe的修改写操作，只允许在源dataframe上进行，一步到位

# %% [markdown]
# ### 3、解决方法1
# 将get+set的两步操作，改成set的一步操作

# %%
df.loc[condition, "wen_cha"] = df["bWendu"] - df["yWendu"]

# %%
df[condition].head()
# Out:
#            ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  \
# 59  2018-03-01       8      -3     多云       西南风   1-2级   46       优         1
# 60  2018-03-02       9      -1   晴~多云        北风   1-2级   95       良         2
# 61  2018-03-03      13       3   多云~阴        北风   1-2级  214    重度污染         5
# 62  2018-03-04       7      -2   阴~多云       东南风   1-2级  144    轻度污染         3
# 63  2018-03-05       8      -3      晴        南风   1-2级   94       良         2
#
#     wen_cha
# 59     11.0
# 60     10.0
# 61     10.0
# 62      9.0
# 63     11.0

# %% [markdown]
# ### 4、解决方法2
#
# 如果需要预筛选数据做后续的处理分析，使用copy复制dataframe

# %%
df_month3 = df[condition].copy()

# %%
df_month3.head()
# Out:
#            ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  \
# 59  2018-03-01       8      -3     多云       西南风   1-2级   46       优         1
# 60  2018-03-02       9      -1   晴~多云        北风   1-2级   95       良         2
# 61  2018-03-03      13       3   多云~阴        北风   1-2级  214    重度污染         5
# 62  2018-03-04       7      -2   阴~多云       东南风   1-2级  144    轻度污染         3
# 63  2018-03-05       8      -3      晴        南风   1-2级   94       良         2
#
#     wen_cha
# 59     11.0
# 60     10.0
# 61     10.0
# 62      9.0
# 63     11.0

# %%
df_month3["wencha"] = df_month3["bWendu"] - df_month3["yWendu"]

# %%
df_month3.head()
# Out:
#            ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  \
# 59  2018-03-01       8      -3     多云       西南风   1-2级   46       优         1
# 60  2018-03-02       9      -1   晴~多云        北风   1-2级   95       良         2
# 61  2018-03-03      13       3   多云~阴        北风   1-2级  214    重度污染         5
# 62  2018-03-04       7      -2   阴~多云       东南风   1-2级  144    轻度污染         3
# 63  2018-03-05       8      -3      晴        南风   1-2级   94       良         2
#
#     wen_cha  wencha
# 59     11.0      11
# 60     10.0      10
# 61     10.0      10
# 62      9.0       9
# 63     11.0      11

# %%
df.head()
# Out:
#           ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  \
# 0  2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03       2      -5     多云        北风   1-2级   28       优         1
# 3  2018-01-04       0      -8      阴       东北风   1-2级   28       优         1
# 4  2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优         1
#
#    wen_cha
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting jupyter_contrib_nbextensions
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/33/f0/6e2c00afda860f655fbf0f795f7310bdbf12122846344dfdc803fc7455d5/jupyter_contrib_nbextensions-0.5.1-py2.py3-none-any.whl (20.9 MB)
# Requirement already satisfied: nbconvert>=4.2 in d:\python\lib\site-packages (from jupyter_contrib_nbextensions) (6.0.6)
# Collecting jupyter-nbextensions-configurator>=0.4.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/51/a3/d72d5f2dc10c5ccf5a6f4c79f636bf071a5ce462dedd07af2f70384db6cb/jupyter_nbextensions_configurator-0.4.1.tar.gz (479 kB)
# Collecting jupyter-contrib-core>=0.3.3
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e6/8f/04a752a8b66a66e7092c035e5d87d2502ac7ec07f9fb6059059b6c0dc272/jupyter_contrib_core-0.3.3-py2.py3-none-any.whl (18 kB)
# Collecting pyyaml
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0c/f4/fcdef9ab4e9044edce9c1e50adf175e6e6d9b39276caf0df1eeb9b125260/PyYAML-5.3.1-cp38-cp38-win32.whl (199 kB)
# Requirement already satisfied: tornado in d:\python\lib\site-packages (from jupyter_contrib_nbextensions) (6.0.4)
# Requirement already satisfied: ipython-genutils in d:\python\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Collecting jupyter-latex-envs>=1.3.8
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0e/15/55805de080d5542f76920364635e96e64d3b37f678befdfe3b16aa154205/jupyter_latex_envs-1.4.6.tar.gz (861 kB)
# Requirement already satisfied: lxml in d:\python\lib\site-packages (from jupyter_contrib_nbextensions) (4.5.2)
# Collecting jupyter-highlight-selected-word>=0.1.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/50/d7/19ab7cfd60bf268d2abbacc52d4295a40f52d74dfc0d938e4761ee5e598b/jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: jupyter-core in d:\python\lib\site-packages (from jupyter_contrib_nbextensions) (4.6.3)
# Requirement already satisfied: notebook>=4.0 in d:\python\lib\site-packages (from jupyter_contrib_nbextensions) (6.1.4)
# Requirement already satisfied: traitlets>=4.1 in d:\python\lib\site-packages (from jupyter_contrib_nbextensions) (5.0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: pygments>=2.4.1 in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.6.1)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.4.2)
# Requirement already satisfied: defusedxml in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.6.0)
# Requirement already satisfied: jinja2>=2.4 in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.11.2)
# Requirement already satisfied: jupyterlab-pygments in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.0)
# Requirement already satisfied: testpath in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: nbformat>=4.4 in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.0.7)
# Requirement already satisfied: bleach in d:\python\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (3.2.1)
# Requirement already satisfied: setuptools in d:\python\lib\site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (47.1.0)
# Requirement already satisfied: ipython in d:\python\lib\site-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (7.18.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in d:\python\lib\site-packages (from jupyter-core->jupyter_contrib_nbextensions) (228)
# Requirement already satisfied: jupyter-client>=5.3.4 in d:\python\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (6.1.7)
# Requirement already satisfied: ipykernel in d:\python\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (5.3.4)
# Requirement already satisfied: argon2-cffi in d:\python\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (20.1.0)
# Requirement already satisfied: Send2Trash in d:\python\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\python\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.9.1)
# Requirement already satisfied: prometheus-client in d:\python\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: pyzmq>=17 in d:\python\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (19.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\python\lib\site-packages (from jinja2>=2.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: nest-asyncio in d:\python\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.4.1)
# Requirement already satisfied: async-generator in d:\python\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in d:\python\lib\site-packages (from nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.2.0)
# Requirement already satisfied: packaging in d:\python\lib\site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (20.4)
# Requirement already satisfied: six>=1.9.0 in d:\python\lib\site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.15.0)
# Requirement already satisfied: webencodings in d:\python\lib\site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: pickleshare in d:\python\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in d:\python\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\python\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (3.0.7)
# Requirement already satisfied: decorator in d:\python\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in d:\python\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.4.3)
# Requirement already satisfied: backcall in d:\python\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in d:\python\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_contrib_nbextensions) (2.8.1)
# Requirement already satisfied: cffi>=1.0.0 in d:\python\lib\site-packages (from argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (1.14.2)
# Requirement already satisfied: pywinpty>=0.5; os_name == "nt" in d:\python\lib\site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_contrib_nbextensions) (0.5.7)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\python\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in d:\python\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (20.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\python\lib\site-packages (from packaging->bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.4.7)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in d:\python\lib\site-packages (from jedi>=0.10->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: wcwidth in d:\python\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: pycparser in d:\python\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (2.20)
# Building wheels for collected packages: jupyter-nbextensions-configurator, jupyter-latex-envs
#   Building wheel for jupyter-nbextensions-configurator (setup.py): started
#   Building wheel for jupyter-nbextensions-configurator (setup.py): finished with status 'done'
#   Created wheel for jupyter-nbextensions-configurator: filename=jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl size=465828 sha256=90597bdef25708f1332b754e9e200ab1205ce4292cb1abcac728cd21aa2788db
#   Stored in directory: c:\users\hsx13\appdata\local\pip\cache\wheels\db\cf\1d\567c500de6ed97ddc9cb2b82300e1a19c24382f6795e8b756c
#   Building wheel for jupyter-latex-envs (setup.py): started
#   Building wheel for jupyter-latex-envs (setup.py): finished with status 'done'
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963398 sha256=e106a3b855e9d958919a2c2ad11bc17b4115dc1e5c55a2e05da02ffea8e1e00f
#   Stored in directory: c:\users\hsx13\appdata\local\pip\cache\wheels\5b\5a\4d\5e6f6b0d23e3d89774238dbca529695dfa61290a2a29ca80f0
# Successfully built jupyter-nbextensions-configurator jupyter-latex-envs
# Installing collected packages: jupyter-contrib-core, pyyaml, jupyter-nbextensions-configurator, jupyter-latex-envs, jupyter-highlight-selected-word, jupyter-contrib-nbextensions
# Successfully installed jupyter-contrib-core-0.3.3 jupyter-contrib-nbextensions-0.5.1 jupyter-highlight-selected-word-0.2.0 jupyter-latex-envs-1.4.6 jupyter-nbextensions-configurator-0.4.1 pyyaml-5.3.1
